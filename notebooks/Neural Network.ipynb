# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier

from sklearn.metrics import (accuracy_score,precision_score,recall_score,f1_score,classification_report,confusion_matrix)

file_path = "../data/raw/Tuesday-WorkingHours.pcap_ISCX.csv"
df = pd.read_csv(file_path)


df.columns = df.columns.str.strip()

# Check label distribution
print("Original labels:")
print(df["Label"].value_counts())

# Convert labels:
# BENIGN = 0, Attack = 1
df["Label_binary"] = df["Label"].apply(lambda x: 0 if x == "BENIGN" else 1)

print("\nBinary labels:")
print(df["Label_binary"].value_counts())

X = df.drop(columns=["Label", "Label_binary"])
y = df["Label_binary"].values
X = X.replace([np.inf, -np.inf], np.nan)

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=42,
    stratify=y
)

X_train_clip = X_train.copy()
X_test_clip = X_test.copy()

X_train_clip = X_train_clip.clip(lower=-1e12, upper=1e12)
X_test_clip = X_test_clip.clip(lower=-1e12, upper=1e12)

imputer = SimpleImputer(strategy="median")

X_train_imputed = imputer.fit_transform(X_train_clip)
X_test_imputed = imputer.transform(X_test_clip)
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train_imputed)
X_test_scaled = scaler.transform(X_test_imputed)

# Neural Network Model

nn = MLPClassifier(
    hidden_layer_sizes=(128, 64),
    activation="relu",
    solver="adam",
    alpha=0.0001,
    batch_size=256,
    learning_rate="adaptive",
    learning_rate_init=0.001,
    max_iter=50,
    random_state=42,
    early_stopping=True,
    validation_fraction=0.1,
    n_iter_no_change=5,
    verbose=True
)

nn.fit(X_train_scaled, y_train)

y_pred = nn.predict(X_test_scaled)

print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred, zero_division=0))
print("Recall   :", recall_score(y_test, y_pred, zero_division=0))
print("F1-score :", f1_score(y_test, y_pred, zero_division=0))

print("\nClassification Report:")
print(classification_report(y_test, y_pred, zero_division=0))

#print("\nConfusion Matrix:")
#print(confusion_matrix(y_test, y_pred))
# Out:
# Original labels:
# Label
# BENIGN         432074
# FTP-Patator      7938
# SSH-Patator      5897
# Name: count, dtype: int64
#
# Binary labels:
# Label_binary
# 0    432074
# 1     13835
# Name: count, dtype: int64
# Iteration 1, loss = 0.02717695
# Validation score: 0.997277
# Iteration 2, loss = 0.00771758
# Validation score: 0.997854
# Iteration 3, loss = 0.00620778
# Validation score: 0.997982
# Iteration 4, loss = 0.00499736
# Validation score: 0.998654
# Iteration 5, loss = 0.00438534
# Validation score: 0.998302
# Iteration 6, loss = 0.00404899
# Validation score: 0.998911
# Iteration 7, loss = 0.00363225
# Validation score: 0.999455
# Iteration 8, loss = 0.00334597
# Validation score: 0.999455
# Iteration 9, loss = 0.00343579
# Validation score: 0.997533
# Iteration 10, loss = 0.00313319
# Validation score: 0.999199
# Iteration 11, loss = 0.00311843
# Validation score: 0.999391
# Iteration 12, loss = 0.00291448
# Validation score: 0.999295
# Iteration 13, loss = 0.00271675
# ...

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier

from sklearn.metrics import (accuracy_score,precision_score,recall_score,f1_score,classification_report,confusion_matrix)

file_path = "../data/raw/Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv"
df = pd.read_csv(file_path)


df.columns = df.columns.str.strip()

# Check label distribution
print("Original labels:")
print(df["Label"].value_counts())

# Convert labels:
# BENIGN = 0, Attack = 1
df["Label_binary"] = df["Label"].apply(lambda x: 0 if x == "BENIGN" else 1)

print("\nBinary labels:")
print(df["Label_binary"].value_counts())

X = df.drop(columns=["Label", "Label_binary"])
y = df["Label_binary"].values
X = X.replace([np.inf, -np.inf], np.nan)

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=42,
    stratify=y
)

X_train_clip = X_train.copy()
X_test_clip = X_test.copy()

X_train_clip = X_train_clip.clip(lower=-1e12, upper=1e12)
X_test_clip = X_test_clip.clip(lower=-1e12, upper=1e12)

imputer = SimpleImputer(strategy="median")

X_train_imputed = imputer.fit_transform(X_train_clip)
X_test_imputed = imputer.transform(X_test_clip)
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train_imputed)
X_test_scaled = scaler.transform(X_test_imputed)

# Neural Network Model

nn = MLPClassifier(
    hidden_layer_sizes=(128, 64),
    activation="relu",
    solver="adam",
    alpha=0.0001,
    batch_size=256,
    learning_rate="adaptive",
    learning_rate_init=0.001,
    max_iter=50,
    random_state=42,
    early_stopping=True,
    validation_fraction=0.1,
    n_iter_no_change=5,
    verbose=True
)

nn.fit(X_train_scaled, y_train)

y_pred = nn.predict(X_test_scaled)

print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred, zero_division=0))
print("Recall   :", recall_score(y_test, y_pred, zero_division=0))
print("F1-score :", f1_score(y_test, y_pred, zero_division=0))

print("\nClassification Report:")
print(classification_report(y_test, y_pred, zero_division=0))

#print("\nConfusion Matrix:")
#print(confusion_matrix(y_test, y_pred))
# Out:
# Original labels:
# Label
# PortScan    158930
# BENIGN      127537
# Name: count, dtype: int64
#
# Binary labels:
# Label_binary
# 1    158930
# 0    127537
# Name: count, dtype: int64
# Iteration 1, loss = 0.02334475
# Validation score: 0.998853
# Iteration 2, loss = 0.00317371
# Validation score: 0.999152
# Iteration 3, loss = 0.00237346
# Validation score: 0.999202
# Iteration 4, loss = 0.00285566
# Validation score: 0.999352
# Iteration 5, loss = 0.00167584
# Validation score: 0.999850
# Iteration 6, loss = 0.00122445
# Validation score: 0.999950
# Iteration 7, loss = 0.00138524
# Validation score: 0.999900
# Iteration 8, loss = 0.00107598
# Validation score: 0.999501
# Iteration 9, loss = 0.00100010
# Validation score: 0.999850
# Iteration 10, loss = 0.00096761
# Validation score: 0.999900
# Iteration 11, loss = 0.00120396
# Validation score: 0.999950
# Validation score did not improve more than tol=0.000100 for 5 consecutive epochs. Stopping.
# Accuracy : 0.999848733433402
# ...

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier

from sklearn.metrics import (accuracy_score,precision_score,recall_score,f1_score,classification_report,confusion_matrix)

file_path = "../data/raw/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv"
df = pd.read_csv(file_path)


df.columns = df.columns.str.strip()

# Check label distribution
print("Original labels:")
print(df["Label"].value_counts())

# Convert labels:
# BENIGN = 0, Attack = 1
df["Label_binary"] = df["Label"].apply(lambda x: 0 if x == "BENIGN" else 1)

print("\nBinary labels:")
print(df["Label_binary"].value_counts())

X = df.drop(columns=["Label", "Label_binary"])
y = df["Label_binary"].values
X = X.replace([np.inf, -np.inf], np.nan)

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=42,
    stratify=y
)

X_train_clip = X_train.copy()
X_test_clip = X_test.copy()

X_train_clip = X_train_clip.clip(lower=-1e12, upper=1e12)
X_test_clip = X_test_clip.clip(lower=-1e12, upper=1e12)

imputer = SimpleImputer(strategy="median")

X_train_imputed = imputer.fit_transform(X_train_clip)
X_test_imputed = imputer.transform(X_test_clip)
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train_imputed)
X_test_scaled = scaler.transform(X_test_imputed)

# Neural Network Model

nn = MLPClassifier(
    hidden_layer_sizes=(128, 64),
    activation="relu",
    solver="adam",
    alpha=0.0001,
    batch_size=256,
    learning_rate="adaptive",
    learning_rate_init=0.001,
    max_iter=50,
    random_state=42,
    early_stopping=True,
    validation_fraction=0.1,
    n_iter_no_change=5,
    verbose=True
)

nn.fit(X_train_scaled, y_train)

y_pred = nn.predict(X_test_scaled)

print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred, zero_division=0))
print("Recall   :", recall_score(y_test, y_pred, zero_division=0))
print("F1-score :", f1_score(y_test, y_pred, zero_division=0))

print("\nClassification Report:")
print(classification_report(y_test, y_pred, zero_division=0))

#print("\nConfusion Matrix:")
#print(confusion_matrix(y_test, y_pred))
# Out:
# Original labels:
# Label
# DDoS      128027
# BENIGN     97718
# Name: count, dtype: int64
#
# Binary labels:
# Label_binary
# 1    128027
# 0     97718
# Name: count, dtype: int64
# Iteration 1, loss = 0.03024286
# Validation score: 0.999304
# Iteration 2, loss = 0.00488440
# Validation score: 0.999494
# Iteration 3, loss = 0.00390753
# Validation score: 0.999494
# Iteration 4, loss = 0.00332168
# Validation score: 0.999430
# Iteration 5, loss = 0.00290067
# Validation score: 0.999557
# Iteration 6, loss = 0.00304994
# Validation score: 0.999430
# Iteration 7, loss = 0.00291436
# Validation score: 0.999747
# Iteration 8, loss = 0.00211628
# Validation score: 0.999367
# Iteration 9, loss = 0.00224491
# Validation score: 0.999684
# Iteration 10, loss = 0.00206167
# Validation score: 0.999430
# Iteration 11, loss = 0.00191794
# Validation score: 0.999810
# Iteration 12, loss = 0.00203756
# Validation score: 0.999873
# Iteration 13, loss = 0.00184258
# Validation score: 0.999810
# ...

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier

from sklearn.metrics import (accuracy_score,precision_score,recall_score,f1_score,classification_report,confusion_matrix)

file_path = "../data/raw/Friday-WorkingHours-Morning.pcap_ISCX.csv"
df = pd.read_csv(file_path)


df.columns = df.columns.str.strip()

# Check label distribution
print("Original labels:")
print(df["Label"].value_counts())

# Convert labels:
# BENIGN = 0, Attack = 1
df["Label_binary"] = df["Label"].apply(lambda x: 0 if x == "BENIGN" else 1)

print("\nBinary labels:")
print(df["Label_binary"].value_counts())

X = df.drop(columns=["Label", "Label_binary"])
y = df["Label_binary"].values
X = X.replace([np.inf, -np.inf], np.nan)

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=42,
    stratify=y
)

X_train_clip = X_train.copy()
X_test_clip = X_test.copy()

X_train_clip = X_train_clip.clip(lower=-1e12, upper=1e12)
X_test_clip = X_test_clip.clip(lower=-1e12, upper=1e12)

imputer = SimpleImputer(strategy="median")

X_train_imputed = imputer.fit_transform(X_train_clip)
X_test_imputed = imputer.transform(X_test_clip)
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train_imputed)
X_test_scaled = scaler.transform(X_test_imputed)

# Neural Network Model

nn = MLPClassifier(
    hidden_layer_sizes=(128, 64),
    activation="relu",
    solver="adam",
    alpha=0.0001,
    batch_size=256,
    learning_rate="adaptive",
    learning_rate_init=0.001,
    max_iter=50,
    random_state=42,
    early_stopping=True,
    validation_fraction=0.1,
    n_iter_no_change=5,
    verbose=True
)

nn.fit(X_train_scaled, y_train)

y_pred = nn.predict(X_test_scaled)

print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred, zero_division=0))
print("Recall   :", recall_score(y_test, y_pred, zero_division=0))
print("F1-score :", f1_score(y_test, y_pred, zero_division=0))

print("\nClassification Report:")
print(classification_report(y_test, y_pred, zero_division=0))

#print("\nConfusion Matrix:")
#print(confusion_matrix(y_test, y_pred))
# Out:
# Original labels:
# Label
# BENIGN    189067
# Bot         1966
# Name: count, dtype: int64
#
# Binary labels:
# Label_binary
# 0    189067
# 1      1966
# Name: count, dtype: int64
# Iteration 1, loss = 0.04106395
# Validation score: 0.996037
# Iteration 2, loss = 0.01527521
# Validation score: 0.996112
# Iteration 3, loss = 0.01323624
# Validation score: 0.996186
# Iteration 4, loss = 0.01267673
# Validation score: 0.996261
# Iteration 5, loss = 0.01246529
# Validation score: 0.996261
# Iteration 6, loss = 0.01238743
# Validation score: 0.996411
# Iteration 7, loss = 0.01186026
# Validation score: 0.996411
# Iteration 8, loss = 0.01156762
# Validation score: 0.996336
# Iteration 9, loss = 0.01203281
# Validation score: 0.996336
# Iteration 10, loss = 0.01143090
# Validation score: 0.996336
# Iteration 11, loss = 0.01133660
# Validation score: 0.996336
# Iteration 12, loss = 0.01134514
# Validation score: 0.996336
# ...

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier

from sklearn.metrics import (accuracy_score,precision_score,recall_score,f1_score,classification_report,confusion_matrix)

file_path = "../data/raw/Monday-WorkingHours.pcap_ISCX.csv"
df = pd.read_csv(file_path)


df.columns = df.columns.str.strip()

# Check label distribution
print("Original labels:")
print(df["Label"].value_counts())

# Convert labels:
# BENIGN = 0, Attack = 1
df["Label_binary"] = df["Label"].apply(lambda x: 0 if x == "BENIGN" else 1)

print("\nBinary labels:")
print(df["Label_binary"].value_counts())

X = df.drop(columns=["Label", "Label_binary"])
y = df["Label_binary"].values
X = X.replace([np.inf, -np.inf], np.nan)

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=42,
    stratify=y
)

X_train_clip = X_train.copy()
X_test_clip = X_test.copy()

X_train_clip = X_train_clip.clip(lower=-1e12, upper=1e12)
X_test_clip = X_test_clip.clip(lower=-1e12, upper=1e12)

imputer = SimpleImputer(strategy="median")

X_train_imputed = imputer.fit_transform(X_train_clip)
X_test_imputed = imputer.transform(X_test_clip)
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train_imputed)
X_test_scaled = scaler.transform(X_test_imputed)

# Neural Network Model

nn = MLPClassifier(
    hidden_layer_sizes=(128, 64),
    activation="relu",
    solver="adam",
    alpha=0.0001,
    batch_size=256,
    learning_rate="adaptive",
    learning_rate_init=0.001,
    max_iter=50,
    random_state=42,
    early_stopping=True,
    validation_fraction=0.1,
    n_iter_no_change=5,
    verbose=True
)

nn.fit(X_train_scaled, y_train)

y_pred = nn.predict(X_test_scaled)

print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred, zero_division=0))
print("Recall   :", recall_score(y_test, y_pred, zero_division=0))
print("F1-score :", f1_score(y_test, y_pred, zero_division=0))

print("\nClassification Report:")
print(classification_report(y_test, y_pred, zero_division=0))

#print("\nConfusion Matrix:")
#print(confusion_matrix(y_test, y_pred))
# Out:
# Original labels:
# Label
# BENIGN    529918
# Name: count, dtype: int64
#
# Binary labels:
# Label_binary
# 0    529918
# Name: count, dtype: int64
# Iteration 1, loss = 0.00510619
# Validation score: 1.000000
# Iteration 2, loss = 0.00004249
# Validation score: 1.000000
# Iteration 3, loss = 0.00003701
# Validation score: 1.000000
# Iteration 4, loss = 0.00003429
# Validation score: 1.000000
# Iteration 5, loss = 0.00003167
# Validation score: 1.000000
# Iteration 6, loss = 0.00002857
# Validation score: 1.000000
# Iteration 7, loss = 0.00002470
# Validation score: 1.000000
# Validation score did not improve more than tol=0.000100 for 5 consecutive epochs. Stopping.
# Accuracy : 1.0
# Precision: 0.0
# Recall   : 0.0
# F1-score : 0.0
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    158976
#
#     accuracy                           1.00    158976
# ...

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier

from sklearn.metrics import (accuracy_score,precision_score,recall_score,f1_score,classification_report,confusion_matrix)

file_path = "../data/raw/Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv"
df = pd.read_csv(file_path)


df.columns = df.columns.str.strip()

# Check label distribution
print("Original labels:")
print(df["Label"].value_counts())

# Convert labels:
# BENIGN = 0, Attack = 1
df["Label_binary"] = df["Label"].apply(lambda x: 0 if x == "BENIGN" else 1)

print("\nBinary labels:")
print(df["Label_binary"].value_counts())

X = df.drop(columns=["Label", "Label_binary"])
y = df["Label_binary"].values
X = X.replace([np.inf, -np.inf], np.nan)

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=42,
    stratify=y
)

X_train_clip = X_train.copy()
X_test_clip = X_test.copy()

X_train_clip = X_train_clip.clip(lower=-1e12, upper=1e12)
X_test_clip = X_test_clip.clip(lower=-1e12, upper=1e12)

imputer = SimpleImputer(strategy="median")

X_train_imputed = imputer.fit_transform(X_train_clip)
X_test_imputed = imputer.transform(X_test_clip)
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train_imputed)
X_test_scaled = scaler.transform(X_test_imputed)

# Neural Network Model

nn = MLPClassifier(
    hidden_layer_sizes=(128, 64),
    activation="relu",
    solver="adam",
    alpha=0.0001,
    batch_size=256,
    learning_rate="adaptive",
    learning_rate_init=0.001,
    max_iter=50,
    random_state=42,
    early_stopping=True,
    validation_fraction=0.1,
    n_iter_no_change=5,
    verbose=True
)

nn.fit(X_train_scaled, y_train)

y_pred = nn.predict(X_test_scaled)

print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred, zero_division=0))
print("Recall   :", recall_score(y_test, y_pred, zero_division=0))
print("F1-score :", f1_score(y_test, y_pred, zero_division=0))

print("\nClassification Report:")
print(classification_report(y_test, y_pred, zero_division=0))

#print("\nConfusion Matrix:")
#print(confusion_matrix(y_test, y_pred))
# Out:
# Original labels:
# Label
# BENIGN          288566
# Infiltration        36
# Name: count, dtype: int64
#
# Binary labels:
# Label_binary
# 0    288566
# 1        36
# Name: count, dtype: int64
# Iteration 1, loss = 0.01105487
# Validation score: 0.999901
# Iteration 2, loss = 0.00060982
# Validation score: 0.999901
# Iteration 3, loss = 0.00045367
# Validation score: 0.999901
# Iteration 4, loss = 0.00028394
# Validation score: 0.999951
# Iteration 5, loss = 0.00030694
# Validation score: 0.999901
# Iteration 6, loss = 0.00080172
# Validation score: 0.999951
# Iteration 7, loss = 0.00029238
# Validation score: 0.999951
# Validation score did not improve more than tol=0.000100 for 5 consecutive epochs. Stopping.
# Accuracy : 0.9999307007311072
# Precision: 0.7777777777777778
# Recall   : 0.6363636363636364
# F1-score : 0.7
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     86570
# ...

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier

from sklearn.metrics import (accuracy_score,precision_score,recall_score,f1_score,classification_report,confusion_matrix)

file_path = "../data/raw/Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv"
df = pd.read_csv(file_path)


df.columns = df.columns.str.strip()

# Check label distribution
print("Original labels:")
print(df["Label"].value_counts())

# Convert labels:
# BENIGN = 0, Attack = 1
df["Label_binary"] = df["Label"].apply(lambda x: 0 if x == "BENIGN" else 1)

print("\nBinary labels:")
print(df["Label_binary"].value_counts())

X = df.drop(columns=["Label", "Label_binary"])
y = df["Label_binary"].values
X = X.replace([np.inf, -np.inf], np.nan)

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=42,
    stratify=y
)

X_train_clip = X_train.copy()
X_test_clip = X_test.copy()

X_train_clip = X_train_clip.clip(lower=-1e12, upper=1e12)
X_test_clip = X_test_clip.clip(lower=-1e12, upper=1e12)

imputer = SimpleImputer(strategy="median")

X_train_imputed = imputer.fit_transform(X_train_clip)
X_test_imputed = imputer.transform(X_test_clip)
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train_imputed)
X_test_scaled = scaler.transform(X_test_imputed)

# Neural Network Model

nn = MLPClassifier(
    hidden_layer_sizes=(128, 64),
    activation="relu",
    solver="adam",
    alpha=0.0001,
    batch_size=256,
    learning_rate="adaptive",
    learning_rate_init=0.001,
    max_iter=50,
    random_state=42,
    early_stopping=True,
    validation_fraction=0.1,
    n_iter_no_change=5,
    verbose=True
)

nn.fit(X_train_scaled, y_train)

y_pred = nn.predict(X_test_scaled)

print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred, zero_division=0))
print("Recall   :", recall_score(y_test, y_pred, zero_division=0))
print("F1-score :", f1_score(y_test, y_pred, zero_division=0))

print("\nClassification Report:")
print(classification_report(y_test, y_pred, zero_division=0))

#print("\nConfusion Matrix:")
#print(confusion_matrix(y_test, y_pred))
# Out:
# Original labels:
# Label
# BENIGN                        168186
# Web Attack � Brute Force        1507
# Web Attack � XSS                 652
# Web Attack � Sql Injection        21
# Name: count, dtype: int64
#
# Binary labels:
# Label_binary
# 0    168186
# 1      2180
# Name: count, dtype: int64
# Iteration 1, loss = 0.03473013
# Validation score: 0.994969
# Iteration 2, loss = 0.01330455
# Validation score: 0.995221
# Iteration 3, loss = 0.01107992
# Validation score: 0.996646
# Iteration 4, loss = 0.00985036
# Validation score: 0.996646
# Iteration 5, loss = 0.00938955
# Validation score: 0.996646
# Iteration 6, loss = 0.00905469
# Validation score: 0.996730
# Iteration 7, loss = 0.00894026
# Validation score: 0.996646
# Iteration 8, loss = 0.00894784
# Validation score: 0.996562
# Iteration 9, loss = 0.00865728
# Validation score: 0.996730
# Validation score did not improve more than tol=0.000100 for 5 consecutive epochs. Stopping.
# Accuracy : 0.9970847192330268
# ...

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier

from sklearn.metrics import (accuracy_score,precision_score,recall_score,f1_score,classification_report,confusion_matrix)

file_path = "../data/raw/Wednesday-workingHours.pcap_ISCX.csv"
df = pd.read_csv(file_path)


df.columns = df.columns.str.strip()

# Check label distribution
print("Original labels:")
print(df["Label"].value_counts())

# Convert labels:
# BENIGN = 0, Attack = 1
df["Label_binary"] = df["Label"].apply(lambda x: 0 if x == "BENIGN" else 1)

print("\nBinary labels:")
print(df["Label_binary"].value_counts())

X = df.drop(columns=["Label", "Label_binary"])
y = df["Label_binary"].values
X = X.replace([np.inf, -np.inf], np.nan)

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=42,
    stratify=y
)

X_train_clip = X_train.copy()
X_test_clip = X_test.copy()

X_train_clip = X_train_clip.clip(lower=-1e12, upper=1e12)
X_test_clip = X_test_clip.clip(lower=-1e12, upper=1e12)

imputer = SimpleImputer(strategy="median")

X_train_imputed = imputer.fit_transform(X_train_clip)
X_test_imputed = imputer.transform(X_test_clip)
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train_imputed)
X_test_scaled = scaler.transform(X_test_imputed)

# Neural Network Model

nn = MLPClassifier(
    hidden_layer_sizes=(128, 64),
    activation="relu",
    solver="adam",
    alpha=0.0001,
    batch_size=256,
    learning_rate="adaptive",
    learning_rate_init=0.001,
    max_iter=50,
    random_state=42,
    early_stopping=True,
    validation_fraction=0.1,
    n_iter_no_change=5,
    verbose=True
)

nn.fit(X_train_scaled, y_train)

y_pred = nn.predict(X_test_scaled)

print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred, zero_division=0))
print("Recall   :", recall_score(y_test, y_pred, zero_division=0))
print("F1-score :", f1_score(y_test, y_pred, zero_division=0))

print("\nClassification Report:")
print(classification_report(y_test, y_pred, zero_division=0))

#print("\nConfusion Matrix:")
#print(confusion_matrix(y_test, y_pred))
# Out:
# Original labels:
# Label
# BENIGN              440031
# DoS Hulk            231073
# DoS GoldenEye        10293
# DoS slowloris         5796
# DoS Slowhttptest      5499
# Heartbleed              11
# Name: count, dtype: int64
#
# Binary labels:
# Label_binary
# 0    440031
# 1    252672
# Name: count, dtype: int64
# Iteration 1, loss = 0.04349750
# Validation score: 0.990637
# Iteration 2, loss = 0.02676450
# Validation score: 0.991483
# Iteration 3, loss = 0.02437872
# Validation score: 0.991462
# Iteration 4, loss = 0.02298097
# Validation score: 0.991524
# Iteration 5, loss = 0.02135233
# Validation score: 0.992019
# Iteration 6, loss = 0.02058294
# Validation score: 0.992308
# Iteration 7, loss = 0.01948748
# Validation score: 0.993050
# Iteration 8, loss = 0.01851624
# Validation score: 0.992823
# Iteration 9, loss = 0.01788333
# Validation score: 0.996082
# Iteration 10, loss = 0.01740296
# Validation score: 0.996205
# Iteration 11, loss = 0.01676793
# ...

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier

from sklearn.metrics import (accuracy_score,precision_score,recall_score,f1_score,classification_report,confusion_matrix)

file_path = "../data/raw/Friday-WorkingHours-Morning.pcap_ISCX.csv"
df = pd.read_csv(file_path)


df.columns = df.columns.str.strip()

# Check label distribution
print("Original labels:")
print(df["Label"].value_counts())

# Convert labels:
# BENIGN = 0, Attack = 1
df["Label_binary"] = df["Label"].apply(lambda x: 0 if x == "BENIGN" else 1)

print("\nBinary labels:")
print(df["Label_binary"].value_counts())

X = df.drop(columns=["Label", "Label_binary"])
y = df["Label_binary"].values
X = X.replace([np.inf, -np.inf], np.nan)

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=42,
    stratify=y
)

X_train_clip = X_train.copy()
X_test_clip = X_test.copy()

X_train_clip = X_train_clip.clip(lower=-1e12, upper=1e12)
X_test_clip = X_test_clip.clip(lower=-1e12, upper=1e12)

imputer = SimpleImputer(strategy="median")

X_train_imputed = imputer.fit_transform(X_train_clip)
X_test_imputed = imputer.transform(X_test_clip)
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train_imputed)
X_test_scaled = scaler.transform(X_test_imputed)

# Neural Network Model

nn = MLPClassifier(
    hidden_layer_sizes=(128, 64),
    activation="relu",
    solver="adam",
    alpha=0.0001,
    batch_size=256,
    learning_rate="adaptive",
    learning_rate_init=0.001,
    max_iter=50,
    random_state=42,
    early_stopping=True,
    validation_fraction=0.1,
    n_iter_no_change=5,
    verbose=True
)

nn.fit(X_train_scaled, y_train)

y_pred = nn.predict(X_test_scaled)

print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred, zero_division=0))
print("Recall   :", recall_score(y_test, y_pred, zero_division=0))
print("F1-score :", f1_score(y_test, y_pred, zero_division=0))

print("\nClassification Report:")
print(classification_report(y_test, y_pred, zero_division=0))

#print("\nConfusion Matrix:")
#print(confusion_matrix(y_test, y_pred))
# Out:
# Original labels:
# Label
# BENIGN    189067
# Bot         1966
# Name: count, dtype: int64
#
# Binary labels:
# Label_binary
# 0    189067
# 1      1966
# Name: count, dtype: int64
# Iteration 1, loss = 0.04106395
# Validation score: 0.996037
# Iteration 2, loss = 0.01527521
# Validation score: 0.996112
# Iteration 3, loss = 0.01323624
# Validation score: 0.996186
# Iteration 4, loss = 0.01267673
# Validation score: 0.996261
# Iteration 5, loss = 0.01246529
# Validation score: 0.996261
# Iteration 6, loss = 0.01238743
# Validation score: 0.996411
# Iteration 7, loss = 0.01186026
# Validation score: 0.996411
# Iteration 8, loss = 0.01156762
# Validation score: 0.996336
# Iteration 9, loss = 0.01203281
# Validation score: 0.996336
# Iteration 10, loss = 0.01143090
# Validation score: 0.996336
# Iteration 11, loss = 0.01133660
# Validation score: 0.996336
# Iteration 12, loss = 0.01134514
# Validation score: 0.996336
# ...
